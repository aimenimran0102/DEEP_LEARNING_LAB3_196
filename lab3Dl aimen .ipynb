# %%
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Load data
data = pd.read_csv("Salary_dataset.csv")
#print(data)

# %%
# Extract features and target
X = data[['YearsExperience']]
Y = data['Salary']

# %%
# Create and train the model
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Predict salary for 3 and 10 years of experience
experience_years = [[3], [10]]
predicted_salaries = model.predict(experience_years)

print(f"The Predicted Salary for 3 Years of Experience is: {predicted_salaries[0]}")
print(f"The Predicted Salary for 10 Years of Experience is: {predicted_salaries[1]}")
# Out:
# The Predicted Salary for 3 Years of Experience is: 53198.09093088843
# The Predicted Salary for 10 Years of Experience is: 119347.82718107395
# C:\Users\Muhammad Umer\.anaconda\anacando navigator\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Plot
plt.scatter(X, Y, color='green', label='Actual Data')
plt.plot(X, model.predict(X), color='blue', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()

# %%
print("AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#01 ")
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# Load data
data = pd.read_csv("Salary_dataset.csv")
#print(data)
# Extract features and target
X = data[['YearsExperience']]
Y = data['Salary']
# Create and train the model
model = LinearRegression()
model.fit(X, Y)
# Predict salary for 3 and 10 years of experience
experience_years = [[3], [10]]
predicted_salaries = model.predict(experience_years)
print(f"The Predicted Salary for 3 Years of Experience is: {predicted_salaries[0]}")
print(f"The Predicted Salary for 10 Years of Experience is: {predicted_salaries[1]}")
# Plot
plt.scatter(X, Y, color='purple', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()
# Out:
# AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#01
# C:\Users\Muhammad Umer\.anaconda\anacando navigator\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# The Predicted Salary for 3 Years of Experience is: 53198.09093088843
# The Predicted Salary for 10 Years of Experience is: 119347.82718107395

# %%
print("AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#03 ")
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# Load data
data = pd.read_csv("Salary_dataset.csv")
print(data)
# Extract features and target
X = data[['YearsExperience']]  
Y = data['Salary']             
# Train the model
model = LinearRegression()
model.fit(X, Y)
# Find slope and intercept
slope = model.coef_[0]
intercept = model.intercept_
print("Slope (Coefficient):", slope)
print("Intercept:", intercept)
# Predict salaries for training data
Y_pred = model.predict(X)
# Calculate Mean Squared Error
mse = mean_squared_error(Y, Y_pred)
print("Mean Squared Error:", mse)
# Predict salary for 6 years of experience
predicted_salary = model.predict([[6]])
print("The Predicted Salary Is:", predicted_salary[0])
# Plot
plt.scatter(X, Y, color='purple', label='Actual Data')
plt.plot(X, Y_pred, color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()
# Out:
# AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#03
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# ...

# %%
print("AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#04 ")
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# Load data
data = pd.read_csv("Salary_dataset.csv")
print(data)
# Extract features and target
X = data[['YearsExperience']]  
Y = data['Salary']             
# Train the model
model = LinearRegression()
model.fit(X, Y)
# Find slope and intercept
slope = model.coef_[0]
intercept = model.intercept_
print("Slope (Coefficient):", slope)
print("Intercept:", intercept)
# Predict salaries for training data
Y_pred = model.predict(X)
# Calculate Mean Squared Error
mse = mean_squared_error(Y, Y_pred)
print("Mean Squared Error:", mse)
# Predict salary for 6 years of experience
predicted_salary = model.predict([[6]])
print("The Predicted Salary Is:", predicted_salary[0])
# Plot
plt.scatter(X, Y, color='purple', label='Actual Data')
plt.plot(X, Y_pred, color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()
# Out:
# AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#04
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# ...

# %%
print("AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#02 ")
import pandas as pd
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# Load original dataset (without outlier)
data_original = pd.read_csv("Salary_dataset.csv")
X_orig = data_original[['YearsExperience']]
Y_orig = data_original['Salary']
# Train model on original data
model_orig = LinearRegression()
model_orig.fit(X_orig, Y_orig)
Y_pred_orig = model_orig.predict(X_orig)
# Load modified dataset (with outlier)
data_outlier = pd.read_csv("Salary_dataset_updated.csv")
X_outlier = data_outlier[['YearsExperience']]
Y_outlier = data_outlier['Salary']
# Train model on data with outlier
model_outlier = LinearRegression()
model_outlier.fit(X_outlier, Y_outlier)
Y_pred_outlier = model_outlier.predict(X_outlier)
# Predict salary for 6 years of experience
pred_6_orig = model_orig.predict([[6]])[0]
pred_6_outlier = model_outlier.predict([[6]])[0]
# Print comparison
print("== ORIGINAL DATASET ==")
print("Slope:", model_orig.coef_[0])
print("Intercept:", model_orig.intercept_)
print("MSE:", mean_squared_error(Y_orig, Y_pred_orig))
print("Predicted Salary for 6 YOE:", pred_6_orig)
print("\n== DATASET WITH OUTLIER ==")
print("Slope:", model_outlier.coef_[0])
print("Intercept:", model_outlier.intercept_)
print("MSE:", mean_squared_error(Y_outlier, Y_pred_outlier))
print("Predicted Salary for 6 YOE:", pred_6_outlier)
# Plotting both regression lines
plt.figure(figsize=(10, 6))
plt.scatter(X_outlier, Y_outlier, color='purple', label='Data with Outlier')
plt.plot(X_outlier, Y_pred_outlier, color='red', label='Regression (With Outlier)')
plt.scatter(X_orig, Y_orig, color='orange', label='Original Data')
plt.plot(X_orig, Y_pred_orig, color='blue', label='Regression (Original)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Comparison of Linear Regression: With vs Without Outlier')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# AIMEN IMRAN / 2022F-BSE-196 / LAB#03 / TASK#02
# == ORIGINAL DATASET ==
# Slope: 9449.962321455074
# Intercept: 24848.203966523208
# MSE: 31270951.722280957
# Predicted Salary for 6 YOE: 81547.97789525366
#
# == DATASET WITH OUTLIER ==
# Slope: 7757.842127273813
# Intercept: 37374.5056561233
# MSE: 391791615.4249493
# Predicted Salary for 6 YOE: 83921.55841976618
# C:\Users\Muhammad Umer\.anaconda\anacando navigator\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Muhammad Umer\.anaconda\anacando navigator\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
